# %% [markdown]
# # **Atalhos de Teclado no Jupyter Notebook**
#
# O uso de atalhos de teclado pode otimizar significativamente o tempo no Jupyter Notebook. Aqui estão os principais comandos organizados pelos **modos de operação**: **Comando** e **Edição**.
#
# ---
#
# ## **1. Modo Comando (Command Mode)**
# O **Modo Comando** é utilizado para manipular as células.
# Para ativá-lo, pressione **`Esc`**.
#
# ### **Manipulação de Células**
# - **`A`**: Insere uma nova célula **acima**.
# - **`B`**: Insere uma nova célula **abaixo**.
# - **`D` + `D`**: Deleta a célula atual (pressione `D` duas vezes).
# - **`Z`**: Desfaz a exclusão de uma célula.
# - **`Shift` + `M`**: Mescla a célula atual com a próxima.
# - **`C`**: Copia a célula atual.
# - **`X`**: Recorta a célula atual.
# - **`V`**: Cola a célula **abaixo**.
#
# ### **Executar Células**
# - **`Shift` + `Enter`**: Executa a célula atual e vai para a próxima.
# - **`Ctrl` + `Enter`**: Executa a célula atual sem sair dela.
# - **`Alt` + `Enter`**: Executa a célula atual e insere uma nova célula abaixo.
#
# ### **Navegação**
# - **`Up Arrow` / `Down Arrow`**: Navega entre as células.
# - **`Y`**: Converte a célula para **Código** (Code).
# - **`M`**: Converte a célula para **Markdown**.
# - **`R`**: Converte a célula para texto bruto (**Raw**).
#
# ### **Outros Comandos**
# - **`H`**: Mostra a lista de atalhos de teclado.
# - **`Shift` + `L`**: Mostra ou oculta a numeração de linhas.
# - **`Shift` + `Up` / `Shift` + `Down`**: Seleciona múltiplas células.
#
# ---
#
# ## **2. Modo Edição (Edit Mode)**
# O **Modo Edição** é utilizado para editar o conteúdo das células.
# Para ativá-lo, pressione **`Enter`** ou clique dentro da célula.
#
# ### **Edição de Texto**
# - **`Ctrl` + `A`**: Seleciona todo o texto.
# - **`Ctrl` + `Z`**: Desfaz a última alteração.
# - **`Ctrl` + `Shift` + `Z`**: Refaz a alteração desfeita.
# - **`Ctrl` + `C`**: Copia o texto selecionado.
# - **`Ctrl` + `X`**: Recorta o texto selecionado.
# - **`Ctrl` + `V`**: Cola o texto copiado.
#
# ### **Indentação e Comentários**
# - **`Tab`**: Adiciona indentação (avanço para direita).
# - **`Shift` + `Tab`**: Remove indentação (recuo para esquerda).
# - **`Ctrl` + `/`**: Comenta ou descomenta a linha selecionada.
#
# ### **Execução Rápida**
# - **`Shift` + `Enter`**: Executa a célula atual e vai para a próxima.
# - **`Ctrl` + `Enter`**: Executa a célula atual e permanece nela.
#
# ---
#
# ## **3. Atalhos Úteis Adicionais**
# - **`Ctrl` + `Shift` + `-`**: Divide a célula no cursor.
# - **`Shift` + `J` / `Shift` + `K`**: Seleciona múltiplas células no **Modo Comando**.
# - **`0` + `0`**: Reinicia o kernel (pressione **0** duas vezes).
#
# ---
#
# ## **4. Visualizar ou Customizar Atalhos**
# - Pressione **`H`** no **Modo Comando** para visualizar todos os atalhos disponíveis.
# - Para **editar** ou customizar atalhos, vá em:
#   - **Help** → **Edit Keyboard Shortcuts**.
#
# ---
#
# Pratique esses atalhos e otimize sua produtividade no Jupyter Notebook! 🚀
